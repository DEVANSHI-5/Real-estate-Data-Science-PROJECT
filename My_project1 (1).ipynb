# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
RE = pd.read_csv("Real estate.csv")

# %%
RE.shape
# Out:
# (414, 8)

# %%
RE.head(11)
# Out:
#     No  X1 transaction date  X2 house age  \
# 0    1             2012.917          32.0
# 1    2             2012.917          19.5
# 2    3             2013.583          13.3
# 3    4             2013.500          13.3
# 4    5             2012.833           5.0
# 5    6             2012.667           7.1
# 6    7             2012.667          34.5
# 7    8             2013.417          20.3
# 8    9             2013.500          31.7
# 9   10             2013.417          17.9
# 10  11             2013.083          34.8
#
#     X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                 84.87882                               10
# 1                                306.59470                                9
# 2                                561.98450                                5
# 3                                561.98450                                5
# ...

# %%
RE.tail()
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# ...

# %%
RE.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
RE.dtypes
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
RE2=RE.drop(['X4 number of convenience stores'],axis='columns')
RE2.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X5 latitude  X6 longitude  \
# 0                                84.87882     24.98298     121.54024
# 1                               306.59470     24.98034     121.53951
# 2                               561.98450     24.98746     121.54391
# 3                               561.98450     24.98746     121.54391
# 4                               390.56840     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
RE2.corr()
# Out:
#                                               No  X1 transaction date  \
# No                                      1.000000            -0.048658
# X1 transaction date                    -0.048658             1.000000
# X2 house age                           -0.032808             0.017549
# X3 distance to the nearest MRT station -0.013573             0.060880
# X5 latitude                            -0.010110             0.035058
# X6 longitude                           -0.011059            -0.041082
# Y house price of unit area             -0.028587             0.087491
#
#                                         X2 house age  \
# No                                         -0.032808
# X1 transaction date                         0.017549
# X2 house age                                1.000000
# X3 distance to the nearest MRT station      0.025622
# X5 latitude                                 0.054420
# X6 longitude                               -0.048520
# ...

# %%
q=RE2.loc[1]
q
# Out:
# No                                           2.00000
# X1 transaction date                       2012.91700
# X2 house age                                19.50000
# X3 distance to the nearest MRT station     306.59470
# X5 latitude                                 24.98034
# X6 longitude                               121.53951
# Y house price of unit area                  42.20000
# Name: 1, dtype: float64

# %%
RE2.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
RE2['X2 house age'].unique()
# Out:
# array([32. , 19.5, 13.3,  5. ,  7.1, 34.5, 20.3, 31.7, 17.9, 34.8,  6.3,
#        13. , 20.4, 13.2, 35.7,  0. , 17.7, 16.9,  1.5,  4.5, 10.5, 14.7,
#        10.1, 39.6, 29.3,  3.1, 10.4, 19.2, 25.9, 29.6, 37.9, 16.5, 15.4,
#        13.9, 12. , 16.2, 13.6, 16.8, 36.1, 34.4,  2.7, 36.6, 21.7, 35.9,
#        24.2, 29.4, 31.3, 32.1, 16.1, 33.6,  3.5, 30.3, 11. ,  5.3, 17.2,
#         2.6, 17.5, 40.1,  1. ,  8.5, 30.4, 12.5,  6.6, 35.5, 32.5, 13.8,
#         6.8, 12.3, 20.5, 38.2, 18. , 11.8, 30.8, 25.3, 15.1,  1.8,  8.9,
#        23. ,  9.1, 20.6, 31.9, 40.9,  8. ,  6.4, 28.4, 16.4, 12.7,  1.1,
#        32.7, 12.2, 31.4,  4. ,  8.1, 33.3,  9.9, 14.8, 30.6, 30.9, 16.6,
#        31.5, 38.6,  3.8, 41.3, 38.5, 26.6, 33.4, 18.9, 11.4, 10. , 12.9,
#         5.1, 19.8, 11.9,  2.1,  3.2, 34.9, 35.8,  4.9,  6.5, 30.7, 11.6,
#        15.5, 16. , 13.7, 28.2, 27.6,  8.4, 24. ,  3.6,  4.3, 30.2, 33. ,
#        13.1, 14. , 26.9, 13.5, 17. , 14.1, 20.9, 16.3, 35.3, 43.8,  9.7,
# ...

# %%
RE2['Age']=RE2['X2 house age'].apply(np.round)
RE3=RE2.drop(['X2 house age'],axis='columns')
RE3.head()
# Out:
#    No  X1 transaction date  X3 distance to the nearest MRT station  \
# 0   1             2012.917                                84.87882
# 1   2             2012.917                               306.59470
# 2   3             2013.583                               561.98450
# 3   4             2013.500                               561.98450
# 4   5             2012.833                               390.56840
#
#    X5 latitude  X6 longitude  Y house price of unit area   Age
# 0     24.98298     121.54024                        37.9  32.0
# 1     24.98034     121.53951                        42.2  20.0
# 2     24.98746     121.54391                        47.3  13.0
# 3     24.98746     121.54391                        54.8  13.0
# 4     24.97937     121.54245                        43.1   5.0

# %%
RE3["Age"].unique()
# Out:
# array([32., 20., 13.,  5.,  7., 34., 18., 35.,  6., 36.,  0., 17.,  2.,
#         4., 10., 15., 40., 29.,  3., 19., 26., 30., 38., 16., 14., 12.,
#        37., 22., 24., 31., 11.,  1.,  8., 25.,  9., 23., 21., 41., 28.,
#        33., 39., 27., 44., 43.])

# %%
RE3[RE3.Age>40]
# Out:
#       No  X1 transaction date  X3 distance to the nearest MRT station  \
# 94    95             2012.917                               167.59890
# 128  129             2013.083                               124.99120
# 173  174             2013.083                               401.88070
# 192  193             2013.167                                57.58945
# 361  362             2013.083                               281.20500
# 389  390             2013.250                               122.36190
# 392  393             2013.083                               443.80200
#
#      X5 latitude  X6 longitude  Y house price of unit area   Age
# 94      24.96630     121.54026                        41.0  41.0
# 128     24.96674     121.54039                        60.7  41.0
# 173     24.98326     121.54460                        35.1  41.0
# 192     24.96750     121.54069                        42.7  44.0
# 361     24.97345     121.54093                        63.3  41.0
# ...

# %%
RE3['X3 distance to the nearest MRT station']=RE3['X3 distance to the nearest MRT station'].apply(np.round)
RE3.head()
# Out:
#    No  X1 transaction date  X3 distance to the nearest MRT station  \
# 0   1             2012.917                                    85.0
# 1   2             2012.917                                   307.0
# 2   3             2013.583                                   562.0
# 3   4             2013.500                                   562.0
# 4   5             2012.833                                   391.0
#
#    X5 latitude  X6 longitude  Y house price of unit area   Age
# 0     24.98298     121.54024                        37.9  32.0
# 1     24.98034     121.53951                        42.2  20.0
# 2     24.98746     121.54391                        47.3  13.0
# 3     24.98746     121.54391                        54.8  13.0
# 4     24.97937     121.54245                        43.1   5.0

# %%
sns.heatmap(RE3.corr())

# %%
sns.pairplot(RE3)

# %%
RE3.shape
# Out:
# (414, 7)

# %%
RE3['DISTFROMMRT']=RE3['X3 distance to the nearest MRT station']
RE3['LONGITUDE']=RE3['X6 longitude']

RE4=RE3.drop(['X3 distance to the nearest MRT station','X6 longitude'],axis='columns')
RE4
# Out:
#       No  X1 transaction date  X5 latitude  Y house price of unit area   Age  \
# 0      1             2012.917     24.98298                        37.9  32.0
# 1      2             2012.917     24.98034                        42.2  20.0
# 2      3             2013.583     24.98746                        47.3  13.0
# 3      4             2013.500     24.98746                        54.8  13.0
# 4      5             2012.833     24.97937                        43.1   5.0
# ..   ...                  ...          ...                         ...   ...
# 409  410             2013.000     24.94155                        15.4  14.0
# 410  411             2012.667     24.97433                        50.0   6.0
# 411  412             2013.250     24.97923                        40.6  19.0
# 412  413             2013.000     24.96674                        52.5   8.0
# 413  414             2013.500     24.97433                        63.9   6.0
#
#      DISTFROMMRT  LONGITUDE
# ...

# %% [markdown]
# ## Started Building Model

# %%
x=RE4.drop('Y house price of unit area',axis='columns')
x.head()
# Out:
#    No  X1 transaction date  X5 latitude   Age  DISTFROMMRT  LONGITUDE
# 0   1             2012.917     24.98298  32.0         85.0  121.54024
# 1   2             2012.917     24.98034  20.0        307.0  121.53951
# 2   3             2013.583     24.98746  13.0        562.0  121.54391
# 3   4             2013.500     24.98746  13.0        562.0  121.54391
# 4   5             2012.833     24.97937   5.0        391.0  121.54245

# %%
y=RE4['Y house price of unit area']
y.head()
# Out:
# 0    37.9
# 1    42.2
# 2    47.3
# 3    54.8
# 4    43.1
# Name: Y house price of unit area, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
i=LinearRegression()
i.fit(x_train,y_train)
i.score(x_test,y_test)
# Out:
# 0.7041807549094423

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv=ShuffleSplit(n_splits=4,test_size=0.1,random_state=0)
cross_val_score(LinearRegression(),x,y,cv=cv)
# Out:
# array([0.61762126, 0.52440845, 0.49977927, 0.41306809])

# %%
def predict_price(Age,LONGITUDE,DISTFROMMRT):
  f=np.zeros(len(x.columns))
  f[0]= Age
  f[1]=LONGITUDE
  f[2]=DISTFROMMRT
  return i.predict([f])[0]

# %%
predict_price(20,121.54391,391.0)
# Out:
# 88024.0116607176

# %%
predict_price(24,125.53910,300.0)
# Out:
# 64144.460414577625
